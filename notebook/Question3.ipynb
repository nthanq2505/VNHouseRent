# %% [markdown]
# ### <center>📜 Question 3: Giá tiền trọ theo năm. Tại sao mỗi năm lại có sự tăng giảm như vậy. </center>
#
# #### Tác dụng:
# - Evaluate the price of accommodation every year

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🎖 1. Get newest data

# %%
HCMHouseRent = pd.read_csv('../data/HCMHouseRentPreprocessing.csv')
HCMHouseRent
# Out:
#         id                                              title    price  \
# 0        0  Cho thuê nhà trọ mới sạch đẹp tại Lê Đình Cẩn,...  2200000
# 1        1  Cho thuê phòng trọ giá rẻ ở mặt tiền hẻm lớn Đ...  2500000
# 2        2  Cho thuê phòng trọ kdc Nam Long-Trần Trọng Cun...  3500000
# 3        3  Phòng trọ giá rẻ ngay cổng khu chế xuất Tân Th...  1500000
# 4        4  Cho thuê phòng có gác, không gác, tolet riêng ...  3500000
# ...    ...                                                ...      ...
# 8943  9497           Cho thuê phòng trọ gần trung tâm quận 11  2200000
# 8944  9498  Cho thuê phòng hoặc tầng 1 và 2 nhà mặt tiền 1...  2500000
# 8945  9499  Phòng FULL NOI THAT THOÁNG ĐẸP NHƯ HÌNH GẦN LÊ...  3500000
# 8946  9500   CHÍNH CHỦ CHO THUÊ CĂN HỘ MINI TẠI TRUNG TÂM Q11  5000000
# 8947  9501         Nhượng lại phòng gần lotte 3.2 lê đại hành  3500000
#
#        published  acreage                          street  \
# 0     2022-05-16     20.0                     Lê Đình Cẩn
# 1     2022-04-20     20.0  487/35/25 Đường Huỳnh Tấn Phát
# 2     2022-05-10     30.0                        Đường 10
# 3     2022-05-05     30.0           283/15 Huỳnh Tấn Phát
# 4     2022-01-05     18.0                       Lê Văn Sỹ
# ...          ...      ...                             ...
# 8943  2020-10-30     14.0       102/9/11a Đường Bình Thới
# 8944  2020-11-23     12.0         177 Đường Tôn Thất Hiệp
# 8945  2022-07-28     20.0               212 Đường Lò Siêu
# 8946  2020-11-25     30.0              127/17 Đường Âu Cơ
# 8947  2021-03-08     12.0             Đường Tôn Thất Hiệp
#
#                        ward        district
# 0            Phường Tân Tạo   Quận Bình Tân
# 1     Phường Tân Thuận Đông          Quận 7
# 2     Phường Tân Thuận Đông          Quận 7
# 3     Phường Tân Thuận Đông          Quận 7
# 4                 Phường 14  Quận Phú Nhuận
# ...                     ...             ...
# 8943              Phường 14         Quận 11
# 8944              Phường 12         Quận 11
# 8945              Phường 12         Quận 11
# 8946              Phường 14         Quận 11
# 8947              Phường 12         Quận 11
#
# [8948 rows x 8 columns]

# %% [markdown]
# > Convert column `Published` from str to datetime

# %%
df = {}
HCMHouseRent['published'] = pd.to_datetime(HCMHouseRent['published'], format='%Y/%m/%d')
df['published'] = HCMHouseRent.groupby(HCMHouseRent['published'].dt.year, axis=0)['price'].mean()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['published'].index, df['published'].values)
plt.xlabel('Năm')
plt.ylabel('Trung bình tiền trọ')
plt.title('Giá tiền trọ theo năm')
plt.show()

# %% [markdown]
# ### What are benefits of finding the answer?
# - We can know  the rental rates fluctuated in HCM City
# - As we can see, during the years (2018 - 2020) of the covid epidemic, the price of accommodation has decreased significantly
