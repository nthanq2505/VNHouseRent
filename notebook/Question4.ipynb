# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the data
df = pd.read_csv('../data/HCMHouseRentPreprocessing.csv')  
df.head(10)
# Out:
#    id                                              title    price   published  \
# 0   0  Cho thuê nhà trọ mới sạch đẹp tại Lê Đình Cẩn,...  2200000  2022-05-16
# 1   1  Cho thuê phòng trọ giá rẻ ở mặt tiền hẻm lớn Đ...  2500000  2022-04-20
# 2   2  Cho thuê phòng trọ kdc Nam Long-Trần Trọng Cun...  3500000  2022-05-10
# 3   3  Phòng trọ giá rẻ ngay cổng khu chế xuất Tân Th...  1500000  2022-05-05
# 4   4  Cho thuê phòng có gác, không gác, tolet riêng ...  3500000  2022-01-05
# 5   5  Phòng cho thuê dành cho người đi làm, gần nhiề...  2200000  2020-11-05
# 6   6  Cho thuê phòng ( nguyên tầng) ban công mặt tiề...  4500000  2022-03-10
# 7   7  PHÒNG ĐẸP MỚI XÂY,KHÔNG CHUNG CHỦ ,ĐƯỜNG AN DƯ...  3000000  2022-07-19
# 8   8  Phòng 25m2 full tiện nghi Nguyễn Thiện Thuật, ...  4500000  2022-03-30
# 9   9  Chính chủ cho thuê phòng 18m2 tai Đặng Văn Ngữ...  3000000  2020-11-05
#
#    acreage                          street                   ward  \
# 0     20.0                     Lê Đình Cẩn         Phường Tân Tạo
# 1     20.0  487/35/25 Đường Huỳnh Tấn Phát  Phường Tân Thuận Đông
# 2     30.0                        Đường 10  Phường Tân Thuận Đông
# 3     30.0           283/15 Huỳnh Tấn Phát  Phường Tân Thuận Đông
# 4     18.0                       Lê Văn Sỹ              Phường 14
# 5     15.0       174/15 Đường Đặng Văn Ngữ              Phường 14
# 6     20.0          311 Nguyễn Thiện Thuật               Phường 1
# 7     16.0                      Đường số 4              Phường 16
# 8     25.0          Phố Nguyễn Thiện Thuật               Phường 1
# 9     18.0              Đường Đặng Văn Ngữ              Phường 14
#
#          district
# 0   Quận Bình Tân
# 1          Quận 7
# 2          Quận 7
# 3          Quận 7
# 4  Quận Phú Nhuận
# 5  Quận Phú Nhuận
# 6          Quận 3
# 7          Quận 8
# 8          Quận 3
# 9  Quận Phú Nhuận

# %% [markdown]
# # <font color="green"><b>Question 4:</b></font>
# ### <strong>What is the question?</strong>
# &#9889; Giá tiền trọ theo quận, huyện và thống kê đa số các phòng trọ có diện tích bao nhiêu?
# ### <strong>What are benefits of finding the answer?</strong>
# - Biết được giá tiền trọ mỗi quận, kết hợp với diện tích ta sẽ biết được mỗi quận sẽ khác nhau như thế nào.
# - Từ đó có thể tìm được trọ theo đúng nhu cầu của mỗi người
# ### <strong>How to find the answers of questions by using data?</strong>
# 1. Trung bình giá trọ và diện tích trọ theo quận, huyện
# 2. Thống kê đa số các phòng trọ có diện tích bao nhiêu?
# 3. The third step is find item is the best seller in category is the best seller.
# #### <strong>1. <i>Thống kê theo filter là các quận/huyện về giá tiền và diện tích.</i> </strong>

# %%
df.groupby('district').price.mean().sort_values(ascending=False)
# Out:
# district
# Quận 1              4.606400e+06
# Quận 3              4.236052e+06
# Quận Phú Nhuận      4.109358e+06
# Quận Bình Thạnh     3.865448e+06
# Quận 2              3.811993e+06
# Huyện Bình Chánh    3.744444e+06
# Quận 4              3.619287e+06
# Quận Tân Bình       3.587952e+06
# Quận 7              3.475620e+06
# Quận 10             3.429602e+06
# Quận 8              3.421984e+06
# Quận Gò Vấp         3.421106e+06
# Quận 5              3.406640e+06
# Quận Tân Phú        3.228409e+06
# Quận 11             3.040921e+06
# Quận 12             2.731272e+06
# Quận 6              2.710569e+06
# Quận 9              2.687237e+06
# Quận Bình Tân       2.633965e+06
# Quận Thủ Đức        2.632371e+06
# Huyện Nhà Bè        2.303200e+06
# Huyện Hóc Môn       1.615684e+06
# Huyện Củ Chi        1.355263e+06
# Name: price, dtype: float64

# %%
# visualize price by district mean
plt.figure(figsize=(10, 5))
sns.barplot(x=df.groupby('district').price.mean().sort_values(ascending=False).index, y=df.groupby('district').price.mean().sort_values(ascending=False).values)
plt.xticks(rotation=90)
plt.title('Price by district mean')
plt.show()

# %%
df.groupby('district').acreage.mean().sort_values(ascending=False)
# Out:
# district
# Huyện Bình Chánh    40.589744
# Quận Gò Vấp         31.415435
# Quận 2              31.208487
# Quận 6              28.311706
# Quận 9              27.750000
# Quận Thủ Đức        27.668392
# Quận 10             27.565302
# Quận 1              27.341333
# Quận Tân Bình       26.020035
# Quận 4              25.877660
# Quận Bình Tân       25.841779
# Quận 7              25.564738
# Quận 3              25.041418
# Quận 5              25.032720
# Quận 8              24.903529
# Quận 12             24.894015
# Quận Bình Thạnh     24.647497
# Quận Tân Phú        24.621843
# Huyện Củ Chi        24.368421
# Quận Phú Nhuận      24.346284
# Huyện Nhà Bè        23.408000
# Huyện Hóc Môn       23.142105
# Quận 11             22.564252
# Name: acreage, dtype: float64

# %%
# visualize acreage by district mean
plt.figure(figsize=(10, 5))
sns.barplot(x=df.groupby('district').acreage.mean().sort_values(ascending=False).index, y=df.groupby('district').acreage.mean().sort_values(ascending=False).values)
plt.xticks(rotation=90)
plt.title('Acreage by district mean')
plt.show()

# %%
df['price_per_square_meter'] = df['price'] / df['acreage']
df.head(10)
# Out:
#    id                                              title    price   published  \
# 0   0  Cho thuê nhà trọ mới sạch đẹp tại Lê Đình Cẩn,...  2200000  2022-05-16
# 1   1  Cho thuê phòng trọ giá rẻ ở mặt tiền hẻm lớn Đ...  2500000  2022-04-20
# 2   2  Cho thuê phòng trọ kdc Nam Long-Trần Trọng Cun...  3500000  2022-05-10
# 3   3  Phòng trọ giá rẻ ngay cổng khu chế xuất Tân Th...  1500000  2022-05-05
# 4   4  Cho thuê phòng có gác, không gác, tolet riêng ...  3500000  2022-01-05
# 5   5  Phòng cho thuê dành cho người đi làm, gần nhiề...  2200000  2020-11-05
# 6   6  Cho thuê phòng ( nguyên tầng) ban công mặt tiề...  4500000  2022-03-10
# 7   7  PHÒNG ĐẸP MỚI XÂY,KHÔNG CHUNG CHỦ ,ĐƯỜNG AN DƯ...  3000000  2022-07-19
# 8   8  Phòng 25m2 full tiện nghi Nguyễn Thiện Thuật, ...  4500000  2022-03-30
# 9   9  Chính chủ cho thuê phòng 18m2 tai Đặng Văn Ngữ...  3000000  2020-11-05
#
#    acreage                          street                   ward  \
# 0     20.0                     Lê Đình Cẩn         Phường Tân Tạo
# 1     20.0  487/35/25 Đường Huỳnh Tấn Phát  Phường Tân Thuận Đông
# 2     30.0                        Đường 10  Phường Tân Thuận Đông
# 3     30.0           283/15 Huỳnh Tấn Phát  Phường Tân Thuận Đông
# 4     18.0                       Lê Văn Sỹ              Phường 14
# 5     15.0       174/15 Đường Đặng Văn Ngữ              Phường 14
# 6     20.0          311 Nguyễn Thiện Thuật               Phường 1
# 7     16.0                      Đường số 4              Phường 16
# 8     25.0          Phố Nguyễn Thiện Thuật               Phường 1
# 9     18.0              Đường Đặng Văn Ngữ              Phường 14
#
#          district  price_per_square_meter
# 0   Quận Bình Tân           110000.000000
# 1          Quận 7           125000.000000
# 2          Quận 7           116666.666667
# 3          Quận 7            50000.000000
# 4  Quận Phú Nhuận           194444.444444
# 5  Quận Phú Nhuận           146666.666667
# 6          Quận 3           225000.000000
# 7          Quận 8           187500.000000
# 8          Quận 3           180000.000000
# 9  Quận Phú Nhuận           166666.666667

# %%
# choose district to visualize  
district = 'Quận Thủ Đức'
choose_district = df[df['district'] == district]
choose_district = choose_district.sort_values(by='price_per_square_meter', ascending=False)
choose_district.head(20)

#visualize top 10 price by bar chart
choose_district.head(10).plot.bar(x='street', y='price_per_square_meter', rot=90, figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='street'>

# %%
#choose district to visualize histogram acreage 
district = 'Quận 7'
choose_district = df[df['district'] == district]
choose_district = choose_district.sort_values(by='acreage', ascending=False)
choose_district.head(20)

#visualize histogram acreage
plt.figure(figsize=(10, 5))
sns.distplot(choose_district['acreage'], bins=20)
plt.title('Histogram of Acreage')
plt.show()
# Out:
# /home/nqthang/anaconda3/envs/DataScience/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#choose district to visualize percent of the acreage
district = 'Quận 7'
choose_district = df[df['district'] == district]
choose_district = choose_district.sort_values(by='acreage', ascending=False)
choose_district.head(20)

#visualize percent of the acreage
plt.figure(figsize=(10, 5))

# calculate the percent of the acreage
percent = choose_district['acreage'].value_counts(normalize=True) * 100
percent = percent.sort_index()

# plot the percent of the acreage with pie chart
plt.pie(percent, labels=percent.index, autopct='%1.1f%%')
plt.title('Percent of the Acreage')
plt.show()
